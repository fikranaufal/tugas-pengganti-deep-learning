# %% [markdown]
# # **Proyek Pengganti UAS**
# Christopher Raynard (10122003) \
# Muhammad Fikran Naufal (10122097)

# %% [markdown]
# # Tujuan

# %% [markdown]
# Proyek ini bertujuan untuk membangun model untuk memprediksi seakurat mungkin karir dari para lulusan matematika dengan berbagai model *deep learning* yang telah dipelajari.

# %% [markdown]
# # Libraries

# %%
import cv2
import os
import glob
from tqdm import tqdm # Progress bar
import librosa
import random
import numpy as np
from math import pi, cos, sin
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataset

# %%
# dataset
# deskripsi dataset sedetail mungkin (sebelum prepro)

math_df = pd.read_csv("math_job_dataset.csv")

print(math_df)

for i in math_df.items():
  print(f"\nMissing values in dataset:")
  print(math_df.isnull().sum())

print("\n")
#for col in math_df.drop('salary', axis=1):
for col in math_df:
  print:(f"\nUnique entries in each column of dataset:")
  print(math_df[col].unique())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4028/2991879489.py in <cell line: 0>()
#       2 # deskripsi dataset sedetail mungkin (sebelum prepro)
#       3
# ----> 4 math_df = pd.read_csv("math_job_dataset.csv")
#       5
#       6 print(math_df)
#
# ...

# %% [markdown]
# # Dataset (Preprocessed)
# 1. langkah prepro 1
# 2. langkah prepro 2
# 3. Option 3

# %%
# Langkah prepro
# Output prepro sedetail mungkin

# %% [markdown]
# # Model
# 1. model 1
# 2. model 2
# 3. Option 3

# %% [markdown]
# ## Model 1

# %%
# misalkan mlp klasifikasi
